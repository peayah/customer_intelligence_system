# %%
import pandas as pd

raw_articles = pd.read_csv('articles.csv')
raw_customers = pd.read_csv('customers.csv')
raw_transactions = pd.read_csv('transactions.csv')

articles = raw_articles[["customer_id", "t_dat", "artcicle_id", "price", "sales_channel_id"]]

df = pd.json_normalize(raw_data)
