# %%
import pandas as pd
import pyarrow

df = pd.read_pickle("investigated_data.pkl")

# %%
pd.to_datetime(df["t_dat"], format="%Y-%m-%d") # .head(1)
# Out:
# 0          2018-09-20
# 1          2018-09-20
# 2          2018-09-20
# 3          2018-09-20
# 4          2018-09-20
#               ...
# 31788319   2020-09-22
# 31788320   2020-09-22
# 31788321   2020-09-22
# 31788322   2020-09-22
# 31788323   2020-09-22
# Name: t_dat, Length: 31788324, dtype: datetime64[us]

# %%
df.to_pickle('cleaned_data.pkl')
