# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_pickle("cleaned_data.pkl")

# %% [markdown]
# #### Objective
# The objective is to predict which customers are unlikely to make another purchase, in the forseeable future, so that H&M can target retention efforts before those customers are lost.
#
# #### Dataset Timeline
# - Observation period: All purchases up to June 30, 2020
# - Prediction period: July 1, 2020 to September 30, 2020
#
# #### Churn Definition
